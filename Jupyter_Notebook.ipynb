# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Data Science Tools and Ecosystem

# %%
## Introduction
In this notebook, we summarize the tools, languages, and libraries used in Data Science.
We also demonstrate simple arithmetic operations using Python code.

# %%
## Data Science Languages
Some of the popular languages that Data Scientists use are:

1. Python
2. R
3. SQL

# %%
## Data Science Libraries
1. Pandas
2. NumPy
3. Matplotlib
4. Scikit-Learn

# %%
## Data Science Tools

| Tool | Category |
|------|----------|
| Jupyter Notebook | Development Environment |
| RStudio | Development Environment |
| Apache Spark | Big Data Processing |

# %%
## Arithmetic Expression Examples
The following code cell demonstrates how to perform basic arithmetic calculations in Python such as multiplication and addition.

# %%
# Multiplication and addition example
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %%
## Objectives
- List popular languages used for Data Science
- List common libraries used by Data Scientists
- Create tables to organize Data Science tools
- Perform basic arithmetic operations in Python
- Convert time units using Python code

# %%
## Author
김지훈

# %%
## GitHub Repository Link
[Click here to view my notebook](YOUR_GITHUB_LINK)
